# %%
from huggingface_hub import login

login()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\networksecurity\venv\Lib\site-packages\huggingface_hub\_login.py:312, in notebook_login(skip_if_logged_in)
#     311 try:
# --> 312     import ipywidgets.widgets as widgets  # type: ignore
#     313     from IPython.display import display  # type: ignore
#
# ModuleNotFoundError: No module named 'ipywidgets'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 3
#       1 from huggingface_hub import login
# ----> 3 login()
#
# File c:\networksecurity\venv\Lib\site-packages\huggingface_hub\_login.py:114, in login(token, add_to_git_credential, skip_if_logged_in)
#     112     _login(token, add_to_git_credential=add_to_git_credential)
#     113 elif is_notebook():
# ...

# %%
from datasets import load_dataset
ds=load_dataset("Saon110/bd-crop-vegetable-plant-disease-dataset")
ds
# Out:
# ---------------------------------------------------------------------------
# DatasetNotFoundError                      Traceback (most recent call last)
# Cell In[4], line 2
#       1 from datasets import load_dataset
# ----> 2 ds=load_dataset("Saon110/bd-crop-vegetable-plant-disease-dataset")
#       3 ds
#
# File c:\networksecurity\venv\Lib\site-packages\datasets\load.py:1488, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1483 verification_mode = VerificationMode(
#    1484     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    1485 )
#    1487 # Create a dataset builder
# -> 1488 builder_instance = load_dataset_builder(
#    1489     path=path,
#    1490     name=name,
#    1491     data_dir=data_dir,
#    1492     data_files=data_files,
# ...
